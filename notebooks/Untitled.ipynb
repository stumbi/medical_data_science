# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
test_ds = np.load('../data/testing/testAccelerometer.npy')

test_ds
# Out:
# array([[[-2.50998068e+00,  9.19208527e+00,  4.19128448e-01],
#         [-2.37585950e+00,  9.22322083e+00,  5.02954125e-01],
#         [-2.12917256e+00,  9.42679691e+00,  1.15679443e+00],
#         ...,
#         [ 8.77774715e+00,  1.38911143e-01, -4.43557644e+00],
#         [ 8.73942661e+00,  4.79003927e-03, -4.51940203e+00],
#         [ 8.77774715e+00,  1.43701173e-02, -4.45234156e+00]],
#
#        [[ 8.02331567e-01,  1.83937502e+00, -9.73575497e+00],
#         [ 8.47836971e-01,  1.79386973e+00, -9.86987591e+00],
#         [ 8.50231946e-01,  1.82500494e+00, -9.69982910e+00],
#         ...,
#         [ 8.31071794e-01,  1.89446056e+00, -9.61600399e+00],
#         [ 9.19687510e-01,  1.89206553e+00, -9.78365517e+00],
#         [ 7.87961483e-01,  1.83698010e+00, -9.74533463e+00]],
#
#        [[ 1.71004403e+00,  2.28963876e+00, -9.58965874e+00],
#         [ 1.73878431e+00,  2.20341802e+00, -9.56810379e+00],
#         [ 1.80584478e+00,  2.16988778e+00, -9.59923840e+00],
#         ...,
# ...

# %%
len(test_ds[:, 1, 1])
# Out:
# 2288

# %%
len(test_ds[1, :, 1])
# Out:
# 800

# %%
len(test_ds[1, 1, :])
# Out:
# 3

# %%
fig = plt.plot(test_ds[0,:,:])

# %%
fig = plt.plot(test_ds[1,:,:])

# %%
fig = plt.plot(test_ds[:,:,:])
